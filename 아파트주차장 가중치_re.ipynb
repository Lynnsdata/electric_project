# %%
import pandas as pd

# %%
best = pd.read_csv('data/best_score.csv', index_col=0)
best.head()
# Out:
#     cell_id   cell_xcrd  cell_ycrd  overlap  person_cnt  best_score
# 0  86503006  127.165240  37.284084        3     255.975           5
# 1  86374994  127.160760  37.275060        2     174.924           5
# 2  83511270  127.059555  37.318443        3     162.099           5
# 3  85047108  127.113884  37.288887        1     156.700           5
# 4  84471258  127.093300  37.340195        3     150.741           5

# %% [markdown]
# # Best 5점

# %%
best_5 = best[best['best_score'] == 5]
best_5.head()
# Out:
#     cell_id   cell_xcrd  cell_ycrd  overlap  person_cnt  best_score
# 0  86503006  127.165240  37.284084        3     255.975           5
# 1  86374994  127.160760  37.275060        2     174.924           5
# 2  83511270  127.059555  37.318443        3     162.099           5
# 3  85047108  127.113884  37.288887        1     156.700           5
# 4  84471258  127.093300  37.340195        3     150.741           5

# %%
best_5 = best_5[['cell_id', 'cell_ycrd', 'cell_xcrd']]
best_5.head()
# Out:
#     cell_id  cell_ycrd   cell_xcrd
# 0  86503006  37.284084  127.165240
# 1  86374994  37.275060  127.160760
# 2  83511270  37.318443  127.059555
# 3  85047108  37.288887  127.113884
# 4  84471258  37.340195  127.093300

# %%
best_5_dict = best_5.set_index(['cell_id']).T.to_dict('list')
best_5_dict
# Out:
# {86503006: [37.284084, 127.16524],
#  86374994: [37.27506, 127.16076],
#  83511270: [37.318443, 127.059555],
#  85047108: [37.288887, 127.113884],
#  84471258: [37.340195, 127.0933],
#  83943044: [37.22881, 127.075294],
#  84567237: [37.333447, 127.09672],
#  85159177: [37.32315, 127.11765],
#  84087216: [37.310402, 127.07992],
#  83895245: [37.31804, 127.073105],
#  85111182: [37.324047, 127.11596],
#  90902570: [37.211857, 127.32052],
#  84311190: [37.305023, 127.087845],
#  89910687: [37.236588, 127.285515],
#  85159024: [37.254196, 127.118004],
#  83895264: [37.326603, 127.07305],
#  83895244: [37.31759, 127.073105],
#  85191015: [37.251045, 127.11915],
#  87942919: [37.28557, 127.215996],
#  85943027: [37.277718, 127.14552],
#  86582917: [37.246235, 127.16822],
#  87286857: [37.23909, 127.193054],
#  93254247: [37.13263, 127.40346],
#  86295015: [37.28226, 127.15791],
#  84663249: [37.34157, 127.10007],
#  90694539: [37.192017, 127.31324],
#  84583245: [37.337505, 127.09726],
# ...

# %%
apt_parking_best = pd.read_csv('res/아파트주차장.csv', index_col=0)
apt_parking_best
# Out:
#                 소재지명                     도로명         위도          경도    시설구분
# 0        역북신원아침도시아파트      경기도 용인시 처인구 낙은로 11  37.241478  127.196213  아파트주차장
# 1            양지포레스토리      경기도 용인시 처인구 은이로 85  37.218570  127.277012  아파트주차장
# 2         양우내안애에듀퍼스트  경기도 용인시 처인구 경안천로 196-1  37.244875  127.214471  아파트주차장
# 3          힉스유타워 아파트    경기도 용인시 기흥구 중부대로 184  37.265365  127.100578  아파트주차장
# 4         성복역 KCC스위첸     경기도 용인시 수지구 성복1로 62  37.317501  127.065322  아파트주차장
# ..               ...                     ...        ...         ...     ...
# 463     죽전7차현대홈타운1단지       경기 용인시 수지구 탄천상로 7  37.332303  127.111260  아파트주차장
# 464         기흥더샵프라임뷰    경기 용인시 기흥구 구갈로 71-18  37.281678  127.110146  아파트주차장
# 465       기흥역롯데캐슬스카이     경기 용인시 기흥구 중부대로 375  37.265365  127.100578  아파트주차장
# 466     힐스테이트 서천 아파트      경기 용인시 기흥구 서천동로 22  37.240313  127.075595  아파트주차장
# 467  역북2단지 우남퍼스트빌아파트       경기 용인시 처인구 낙은로 59  37.241478  127.196213  아파트주차장
#
# [468 rows x 5 columns]

# %%
apt_parking_best = apt_parking_best[['소재지명', '위도', '경도']]
apt_parking_best
# Out:
#                 소재지명         위도          경도
# 0        역북신원아침도시아파트  37.241478  127.196213
# 1            양지포레스토리  37.218570  127.277012
# 2         양우내안애에듀퍼스트  37.244875  127.214471
# 3          힉스유타워 아파트  37.265365  127.100578
# 4         성복역 KCC스위첸  37.317501  127.065322
# ..               ...        ...         ...
# 463     죽전7차현대홈타운1단지  37.332303  127.111260
# 464         기흥더샵프라임뷰  37.281678  127.110146
# 465       기흥역롯데캐슬스카이  37.265365  127.100578
# 466     힐스테이트 서천 아파트  37.240313  127.075595
# 467  역북2단지 우남퍼스트빌아파트  37.241478  127.196213
#
# [468 rows x 3 columns]

# %%
apt_parking_best_dict = apt_parking_best.set_index(['소재지명']).T.to_dict('list')
apt_parking_best_dict
# Out:
# C:\Users\시달이\AppData\Local\Temp\ipykernel_6472\2310305379.py:1: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   apt_parking_best_dict = apt_parking_best.set_index(['소재지명']).T.to_dict('list')
# {'역북신원아침도시아파트': [37.2414775, 127.1962133],
#  '양지포레스토리': [37.2185696, 127.2770123],
#  '양우내안애에듀퍼스트': [37.2448753, 127.2144711],
#  '힉스유타워 아파트': [37.2653654, 127.1005782],
#  '성복역 KCC스위첸': [37.3175005, 127.0653222],
#  '신흥덕 롯데캐슬레이시티': [37.2897191, 127.1014604],
#  '성복역 롯데캐슬 골드타운': [37.3173486, 127.0657805],
#  '수지파크푸르지오': [37.326677, 127.0990275],
#  '용인기흥 효성해링턴플레이스아파트': [37.2668569, 127.0938951],
#  '용인보라해링턴플레이스아파트': [37.2549828, 127.1146427],
#  '동천센트럴자이아파트': [37.3414282, 127.09015],
#  '스위트홈아파트': [37.2340351, 127.1982669],
#  '인정멜로디': [37.2701831, 127.2123037],
#  '신원1차': [37.2673683, 127.215862],
#  '신원2차': [37.2671718, 127.2174808],
#  '풍산햇빛마을': [37.3326198, 127.2496088],
#  '용인행정타운두산위브2단지': [37.2407937, 127.1685228],
# ...

# %%
! pip install haversine
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from haversine import haversine

# %%
df_all = pd.DataFrame(columns=["best_name", "apt_parking_name", "거리차이", "score"])

for i in range(0, len(best_5_dict)) :
    best_nm = list(best_5_dict.keys())[i]
    best_xy = list(best_5_dict.items())[i][1]

    for j in range(0, len(apt_parking_best_dict)) :
        apt_parking_nm = list(apt_parking_best_dict.keys())[j]
        apt_parking_xy = list(apt_parking_best_dict.items())[j][1]

        ## 최종 거리 계산 결과값
        result = haversine(best_xy, apt_parking_xy, unit='m')

        score = 0
        if result <= 200:
            score = 5
        elif 200 < result <= 400:
            score = 4
        elif 400 < result <= 600:
            score = 3
        elif 600 < result <= 800:
            score = 2
        elif 800 < result <= 1000:
            score = 1
        df_all = pd.concat([df_all, 
                        pd.DataFrame({'best_name':[best_nm],'apt_parking_name':[apt_parking_nm], '거리차이':[result], 'score':[score]})], ignore_index=True)
df_all
# Out:
#        best_name apt_parking_name          거리차이 score
# 0       86503006      역북신원아침도시아파트   5473.427047     0
# 1       86503006          양지포레스토리  12285.767680     0
# 2       86503006       양우내안애에듀퍼스트   6163.493519     0
# 3       86503006        힉스유타워 아파트   6088.276193     0
# 4       86503006       성복역 KCC스위첸   9587.253936     0
# ...          ...              ...           ...   ...
# 146470  83751250     죽전7차현대홈타운1단지   4220.253811     0
# 146471  83751250         기흥더샵프라임뷰   5350.771767     0
# 146472  83751250       기흥역롯데캐슬스카이   6345.635536     0
# 146473  83751250     힐스테이트 서천 아파트   8466.991910     0
# 146474  83751250  역북2단지 우남퍼스트빌아파트  14060.543321     0
#
# [146475 rows x 4 columns]

# %%
df_all_5 = df_all[df_all['score'] == 5]
df_all_5
# Out:
#        best_name apt_parking_name        거리차이 score
# 238     86503006       백현마을경남아너스빌   82.022479     5
# 1698    85047108      새천년그린빌주공2단지  195.500249     5
# 1699    85047108          파크시엘아파트   45.289179     5
# 2072    84471258             동문그린  112.656374     5
# 2937    84567237       초입마을삼익풍림동아  166.912997     5
# ...          ...              ...         ...   ...
# 141845  87430837               삼환  117.618146     5
# 141846  87430837       용인김량장주공2단지  189.681259     5
# 142468  85223189        새터마을모아미래도  190.055383     5
# 144520  85671024      지석마을그대가크레던스   31.787381     5
# 146230  83751250        성복힐스테이트1차  121.088522     5
#
# [331 rows x 4 columns]

# %%
df_all_5 = df_all_5.groupby('apt_parking_name')['score'].sum()
df_all_5 = df_all_5.reset_index()
df_all_5 = df_all_5.rename(columns = {'score' : '5_score'})
df_all_5
# Out:
#              apt_parking_name 5_score
# 0                   갈현마을현대홈타운      15
# 1                강남마을자연앤4,6단지       5
# 2                    광교경남아너스빌      10
# 3                    광교마을45단지       5
# 4    광교상떼빌파크뷰(구 상현마을성원상떼빌아파트)      15
# ..                        ...     ...
# 204                 호수마을서해그랑블      10
# 205                 호수마을주공3단지       5
# 206               휴먼시아흥덕마을1단지       5
# 207                   흥덕마을3단지       5
# 208               흥덕우남퍼스트빌리젠트       5
#
# [209 rows x 2 columns]

# %% [markdown]
# # Best 4점

# %%
best_4 = best[best['best_score'] == 4]
best_4.head()
# Out:
#       cell_id   cell_xcrd  cell_ycrd  overlap  person_cnt  best_score
# 315  85094952  127.115920  37.219936        3      70.010           4
# 316  86694892  127.172200  37.238132        3      70.010           4
# 317  85895006  127.143880  37.266895        3      69.965           4
# 318  86278976  127.157425  37.264233        3      69.940           4
# 319  90086602  127.291800  37.203247        2      69.808           4

# %%
best_4 = best_4[['cell_id', 'cell_ycrd', 'cell_xcrd']]
best_4.head()
# Out:
#       cell_id  cell_ycrd   cell_xcrd
# 315  85094952  37.219936  127.115920
# 316  86694892  37.238132  127.172200
# 317  85895006  37.266895  127.143880
# 318  86278976  37.264233  127.157425
# 319  90086602  37.203247  127.291800

# %%
best_4_dict = best_4.set_index(['cell_id']).T.to_dict('list')
best_4_dict
# Out:
# {85094952: [37.219936, 127.11592],
#  86694892: [37.238132, 127.1722],
#  85895006: [37.266895, 127.14388],
#  86278976: [37.264233, 127.157425],
#  90086602: [37.203247, 127.2918],
#  84823064: [37.26272, 127.10612],
#  85063198: [37.3299, 127.114235],
#  85799002: [37.26238, 127.14052],
#  87654735: [37.194504, 127.20619],
#  87366633: [37.140392, 127.196266],
#  84231199: [37.306816, 127.085014],
#  89830690: [37.235683, 127.2827],
#  85079135: [37.30196, 127.114944],
#  84839029: [37.2474, 127.106766],
#  86630716: [37.157, 127.1703],
#  86199043: [37.292168, 127.15448],
#  88630884: [37.28923, 127.240234],
#  87958894: [37.274754, 127.2166],
#  84375215: [37.3181, 127.090034],
#  84087042: [37.231983, 127.08035],
#  92326377: [37.16505, 127.37075],
#  83767089: [37.24411, 127.06901],
#  83911145: [37.273426, 127.07392],
#  85399096: [37.29343, 127.12627],
#  87702789: [37.220196, 127.20779],
#  89014710: [37.221653, 127.25399],
#  86279020: [37.28406, 127.15734],
# ...

# %%
df_all = pd.DataFrame(columns=["best_name", "apt_parking_name", "거리차이", "score"])

for i in range(0, len(best_4_dict)) :
    best_nm = list(best_4_dict.keys())[i]
    best_xy = list(best_4_dict.items())[i][1]

    for j in range(0, len(apt_parking_best_dict)) :
        apt_parking_nm = list(apt_parking_best_dict.keys())[j]
        apt_parking_xy = list(apt_parking_best_dict.items())[j][1]

        ## 최종 거리 계산 결과값
        result = haversine(best_xy, apt_parking_xy, unit='m')

        score = 0
        if result <= 200:
            score = 5
        elif 200 < result <= 400:
            score = 4
        elif 400 < result <= 600:
            score = 3
        elif 600 < result <= 800:
            score = 2
        elif 800 < result <= 1000:
            score = 1
        df_all = pd.concat([df_all, 
                        pd.DataFrame({'best_name':[best_nm],'apt_parking_name':[apt_parking_nm], '거리차이':[result], 'score':[score]})], ignore_index=True)
df_all
# Out:
#        best_name apt_parking_name          거리차이 score
# 0       85094952      역북신원아침도시아파트   7501.407849     0
# 1       85094952          양지포레스토리  14265.146030     0
# 2       85094952       양우내안애에듀퍼스트   9155.045196     0
# 3       85094952        힉스유타워 아파트   5230.892341     0
# 4       85094952       성복역 KCC스위첸  11736.311063     0
# ...          ...              ...           ...   ...
# 146470  84999068     죽전7차현대홈타운1단지   6983.989650     0
# 146471  84999068         기흥더샵프라임뷰   1367.363307     0
# 146472  84999068       기흥역롯데캐슬스카이   1133.785690     0
# 146473  84999068     힐스테이트 서천 아파트   4591.390692     0
# 146474  84999068  역북2단지 우남퍼스트빌아파트   8054.750830     0
#
# [146475 rows x 4 columns]

# %%
df_all_4 = df_all[df_all['score'] == 5]
df_all_4
# Out:
#        best_name apt_parking_name        거리차이 score
# 488     86694892      행정타운늘푸른오스카빌  164.310484     5
# 890     86694892               진우  107.667514     5
# 1481    86278976    초당마을삼부르네상스아파트    1.773258     5
# 1482    86278976      초당마을 삼부르네상스  120.253175     5
# 2558    84823064        금화마을주공6단지   91.900245     5
# ...          ...              ...         ...   ...
# 144460  85383115        교동마을현대홈타운  165.065736     5
# 144951  83767253      성동마을엘지빌리지6차  165.666197     5
# 144952  83767253          수지자이아파트  193.398876     5
# 145418  83719265       성복센트럴자이아파트  183.716015     5
# 145744  86167020       호수마을동보노빌리티  180.823833     5
#
# [351 rows x 4 columns]

# %%
df_all_4 = df_all_4.groupby('apt_parking_name')['score'].sum()
df_all_4 = df_all_4.reset_index()
df_all_4 = df_all_4.rename(columns = {'score' : '4_score'})
df_all_4
# Out:
#     apt_parking_name 4_score
# 0        e편한세상 수지아파트      10
# 1          갈현마을현대홈타운       5
# 2       강남마을9단지한라비발디       5
# 3       강남마을자연앤4,6단지      10
# 4         공세대주피오레2단지       5
# ..               ...     ...
# 240          흥덕마을3단지      10
# 241        흥덕마을주공4단지      10
# 242       흥덕우미린레이크포레      10
# 243        힐스테이트 광교산      10
# 244          힐스테이트기흥      10
#
# [245 rows x 2 columns]

# %% [markdown]
# # Best 3점

# %%
best_3 = best[best['best_score'] == 3]
best_3.head()
# Out:
#       cell_id   cell_xcrd  cell_ycrd  overlap  person_cnt  best_score
# 630  90710643  127.313690  37.239340        3      56.924           3
# 631  84055207  127.078820  37.305443        3      56.908           3
# 632  87686748  127.207300  37.201267        3      56.900           3
# 633  85335125  127.123955  37.304690        3      56.865           3
# 634  87638699  127.205696  37.177826        3      56.801           3

# %%
best_3 = best_3[['cell_id', 'cell_ycrd', 'cell_xcrd']]
best_3.head()
# Out:
#       cell_id  cell_ycrd   cell_xcrd
# 630  90710643  37.239340  127.313690
# 631  84055207  37.305443  127.078820
# 632  87686748  37.201267  127.207300
# 633  85335125  37.304690  127.123955
# 634  87638699  37.177826  127.205696

# %%
best_3_dict = best_3.set_index(['cell_id']).T.to_dict('list')
best_3_dict
# Out:
# {90710643: [37.23934, 127.31369],
#  84055207: [37.305443, 127.07882],
#  87686748: [37.201267, 127.2073],
#  85335125: [37.30469, 127.123955],
#  87638699: [37.177826, 127.205696],
#  84023154: [37.28065, 127.07783],
#  87814816: [37.23553, 127.21167],
#  84071216: [37.30995, 127.07935],
#  84007224: [37.311745, 127.07709],
#  88375027: [37.346447, 127.231],
#  86327016: [37.283615, 127.159035],
#  84295229: [37.322147, 127.08719],
#  83895268: [37.328407, 127.073044],
#  83447283: [37.32249, 127.057274],
#  84071204: [37.304543, 127.079384],
#  84823062: [37.261818, 127.106125],
#  87190953: [37.279644, 127.18951],
#  84055037: [37.228825, 127.07924],
#  86119036: [37.28675, 127.15169],
#  85750999: [37.25967, 127.13884],
#  86518919: [37.245327, 127.16597],
#  83623263: [37.318455, 127.06351],
#  83815277: [37.3302, 127.07021],
#  84519082: [37.262234, 127.095406],
#  84727153: [37.300114, 127.10254],
#  84167216: [37.312668, 127.082726],
#  85079083: [37.278522, 127.11506],
# ...

# %%
df_all = pd.DataFrame(columns=["best_name", "apt_parking_name", "거리차이", "score"])

for i in range(0, len(best_3_dict)) :
    best_nm = list(best_3_dict.keys())[i]
    best_xy = list(best_3_dict.items())[i][1]

    for j in range(0, len(apt_parking_best_dict)) :
        apt_parking_nm = list(apt_parking_best_dict.keys())[j]
        apt_parking_xy = list(apt_parking_best_dict.items())[j][1]

        ## 최종 거리 계산 결과값
        result = haversine(best_xy, apt_parking_xy, unit='m')

        score = 0
        if result <= 200:
            score = 5
        elif 200 < result <= 400:
            score = 4
        elif 400 < result <= 600:
            score = 3
        elif 600 < result <= 800:
            score = 2
        elif 800 < result <= 1000:
            score = 1
        df_all = pd.concat([df_all, 
                        pd.DataFrame({'best_name':[best_nm],'apt_parking_name':[apt_parking_nm], '거리차이':[result], 'score':[score]})], ignore_index=True)
df_all
# Out:
#        best_name apt_parking_name          거리차이 score
# 0       90710643      역북신원아침도시아파트  10402.078235     0
# 1       90710643          양지포레스토리   3984.857066     0
# 2       90710643       양우내안애에듀퍼스트   8804.473994     0
# 3       90710643        힉스유타워 아파트  19082.956448     0
# 4       90710643       성복역 KCC스위첸  23631.329028     0
# ...          ...              ...           ...   ...
# 146470  85927041     죽전7차현대홈타운1단지   6182.905538     0
# 146471  85927041         기흥더샵프라임뷰   3084.619986     0
# 146472  85927041       기흥역롯데캐슬스카이   4415.842145     0
# 146473  85927041     힐스테이트 서천 아파트   7796.766131     0
# 146474  85927041  역북2단지 우남퍼스트빌아파트   6519.750383     0
#
# [146475 rows x 4 columns]

# %%
df_all_3 = df_all[df_all['score'] == 5]
df_all_3
# Out:
#        best_name apt_parking_name        거리차이 score
# 532     84055207         상현현대성우2차  193.108534     5
# 634     84055207   수지금호베스트빌TheEdu  117.791158     5
# 635     84055207        금호베스트빌4단지  165.255061     5
# 679     84055207      수지금호베스트빌5단지  190.156296     5
# 1368    87686748       한천마을금광베네스타  112.258262     5
# ...          ...              ...         ...   ...
# 143952  85687005    지석마을진흥더루벤스1단지   90.544702     5
# 144420  84967062         금화마을대우현대  173.271384     5
# 144421  84967062        금화마을주공5단지  104.863071     5
# 144794  85367180       용인죽전동부센트레빌   13.977933     5
# 145413  84887222          벽산타운3단지  105.190975     5
#
# [360 rows x 4 columns]

# %%
df_all_3 = df_all_3.groupby('apt_parking_name')['score'].sum()
df_all_3 = df_all_3.reset_index()
df_all_3 = df_all_3.rename(columns = {'score' : '3_score'})
df_all_3
# Out:
#     apt_parking_name 3_score
# 0       강남마을자연앤4,6단지       5
# 1           광교경남아너스빌       5
# 2           광교레이크스위첸       5
# 3           광교마을45단지       5
# 4           광교산자이아파트       5
# ..               ...     ...
# 233        화성파크드림아파트       5
# 234        효천마을신안인스빌      10
# 235      휴먼시아흥덕마을1단지      10
# 236     흥덕11단지경남아너스빌       5
# 237        힐스테이트 광교산       5
#
# [238 rows x 2 columns]

# %% [markdown]
# # Best 2점

# %%
best_2 = best[best['best_score'] == 2]
best_2.head()
# Out:
#       cell_id   cell_xcrd  cell_ycrd  overlap  person_cnt  best_score
# 945  84951062  127.110620  37.265438        3      48.784           2
# 946  84599217  127.097890  37.325340        3      48.737           2
# 947  85127166  127.116554  37.317287        3      48.729           2
# 948  84183198  127.083330  37.305008        3      48.682           2
# 949  83767250  127.068596  37.316673        2      48.660           2

# %%
best_2 = best_2[['cell_id', 'cell_ycrd', 'cell_xcrd']]
best_2.head()
# Out:
#       cell_id  cell_ycrd   cell_xcrd
# 945  84951062  37.265438  127.110620
# 946  84599217  37.325340  127.097890
# 947  85127166  37.317287  127.116554
# 948  84183198  37.305008  127.083330
# 949  83767250  37.316673  127.068596

# %%
best_2_dict = best_2.set_index(['cell_id']).T.to_dict('list')
best_2_dict
# Out:
# {84951062: [37.265438, 127.11062],
#  84599217: [37.32534, 127.09789],
#  85127166: [37.317287, 127.116554],
#  84183198: [37.305008, 127.08333],
#  83767250: [37.316673, 127.068596],
#  84231218: [37.31538, 127.08497],
#  85191066: [37.27403, 127.11903],
#  84455209: [37.31766, 127.09286],
#  84407237: [37.328922, 127.0911],
#  84935204: [37.328983, 127.109726],
#  83959227: [37.31174, 127.07539],
#  84503246: [37.335693, 127.09445],
#  87190869: [37.241783, 127.18966],
#  84423209: [37.316753, 127.09173],
#  85815001: [37.26238, 127.14108],
#  86087067: [37.299816, 127.1505],
#  87878804: [37.23193, 127.21394],
#  83831262: [37.32389, 127.07081],
#  85335121: [37.30289, 127.12396],
#  84375228: [37.32396, 127.09],
#  84999061: [37.266346, 127.112305],
#  84711243: [37.340225, 127.10176],
#  84951111: [37.28752, 127.110504],
#  84551231: [37.33029, 127.096176],
#  84919167: [37.311855, 127.10925],
#  83703276: [37.32658, 127.066284],
#  88358888: [37.283348, 127.23067],
# ...

# %%
df_all = pd.DataFrame(columns=["best_name", "apt_parking_name", "거리차이", "score"])

for i in range(0, len(best_2_dict)) :
    best_nm = list(best_2_dict.keys())[i]
    best_xy = list(best_2_dict.items())[i][1]

    for j in range(0, len(apt_parking_best_dict)) :
        apt_parking_nm = list(apt_parking_best_dict.keys())[j]
        apt_parking_xy = list(apt_parking_best_dict.items())[j][1]

        ## 최종 거리 계산 결과값
        result = haversine(best_xy, apt_parking_xy, unit='m')

        score = 0
        if result <= 200:
            score = 5
        elif 200 < result <= 400:
            score = 4
        elif 400 < result <= 600:
            score = 3
        elif 600 < result <= 800:
            score = 2
        elif 800 < result <= 1000:
            score = 1
        df_all = pd.concat([df_all, 
                        pd.DataFrame({'best_name':[best_nm],'apt_parking_name':[apt_parking_nm], '거리차이':[result], 'score':[score]})], ignore_index=True)
df_all
# Out:
#        best_name apt_parking_name          거리차이 score
# 0       84951062      역북신원아침도시아파트   8030.493095     0
# 1       84951062          양지포레스토리  15623.995230     0
# 2       84951062       양우내안애에듀퍼스트   9471.512868     0
# 3       84951062        힉스유타워 아파트    888.669800     1
# 4       84951062       성복역 KCC스위첸   7040.668039     0
# ...          ...              ...           ...   ...
# 146470  85959026     죽전7차현대홈타운1단지   6806.609379     0
# 146471  85959026         기흥더샵프라임뷰   3210.509260     0
# 146472  85959026       기흥역롯데캐슬스카이   4254.961891     0
# 146473  85959026     힐스테이트 서천 아파트   7498.221057     0
# 146474  85959026  역북2단지 우남퍼스트빌아파트   5993.031327     0
#
# [146475 rows x 4 columns]

# %%
df_all_2 = df_all[df_all['score'] == 5]
df_all_2
# Out:
#        best_name apt_parking_name        거리차이 score
# 270     84951062         금화마을대우현대  103.745032     5
# 271     84951062        금화마을주공5단지  174.183954     5
# 472     84599217         수지파크푸르지오  179.495112     5
# 572     84599217             동보1차   31.791098     5
# 1067    85127166         죽현마을LG자이   19.688780     5
# ...          ...              ...         ...   ...
# 145040  86694893               진우   65.212955     5
# 145875  84919160     신촌마을포스홈타운2단지   19.938647     5
# 146358  85959026         어정마을서희삼정  196.869785     5
# 146424  85959026          신동백아이파크   67.196292     5
# 146425  85959026       신동백서해그랑블2차  117.074757     5
#
# [354 rows x 4 columns]

# %%
df_all_2 = df_all_2.groupby('apt_parking_name')['score'].sum()
df_all_2 = df_all_2.reset_index()
df_all_2 = df_all_2.rename(columns = {'score' : '2_score'})
df_all_2
# Out:
#     apt_parking_name 2_score
# 0        e편한세상 수지아파트      15
# 1          갈현마을현대홈타운       5
# 2       강남마을9단지한라비발디       5
# 3       강남마을자연앤4,6단지      10
# 4         강남마을코오롱하늘채      10
# ..               ...     ...
# 253     흥덕마을7단지힐스테이트      10
# 254        흥덕마을주공4단지       5
# 255       흥덕우미린레이크포레       5
# 256     힐스테이트 구성 아파트       5
# 257          힐스테이트기흥       5
#
# [258 rows x 2 columns]

# %% [markdown]
# # Best 1점

# %%
best_1 = best[best['best_score'] == 1]
best_1.head()
# Out:
#        cell_id   cell_xcrd  cell_ycrd  overlap  person_cnt  best_score
# 1260  84935149  127.109856  37.304195        3      41.701           1
# 1261  91334485  127.335790  37.185740        2      41.688           1
# 1262  84471214  127.093410  37.320366        3      41.647           1
# 1263  85063020  127.114650  37.249676        2      41.630           1
# 1264  84839092  127.106610  37.275790        3      41.627           1

# %%
best_1 = best_1[['cell_id', 'cell_ycrd', 'cell_xcrd']]
best_1.head()
# Out:
#        cell_id  cell_ycrd   cell_xcrd
# 1260  84935149  37.304195  127.109856
# 1261  91334485  37.185740  127.335790
# 1262  84471214  37.320366  127.093410
# 1263  85063020  37.249676  127.114650
# 1264  84839092  37.275790  127.106610

# %%
best_1_dict = best_1.set_index(['cell_id']).T.to_dict('list')
best_1_dict
# Out:
# {84935149: [37.304195, 127.109856],
#  91334485: [37.18574, 127.33579],
#  84471214: [37.320366, 127.09341],
#  85063020: [37.249676, 127.11465],
#  84839092: [37.27579, 127.10661],
#  86375006: [37.280464, 127.160736],
#  83975200: [37.300022, 127.07603],
#  85031178: [37.31998, 127.11316],
#  84887093: [37.2776, 127.1083],
#  85159120: [37.297462, 127.11778],
#  83527306: [37.335117, 127.06002],
#  84423246: [37.33343, 127.091644],
#  84007231: [37.3149, 127.07707],
#  84423219: [37.321262, 127.091705],
#  85047195: [37.328094, 127.11368],
#  85127079: [37.278076, 127.11675],
#  90198668: [37.236156, 127.29566],
#  86550912: [37.243076, 127.16711],
#  84903214: [37.332584, 127.10858],
#  85415174: [37.329037, 127.126656],
#  84471236: [37.33028, 127.09335],
#  86758714: [37.159718, 127.1748],
#  89014966: [37.337032, 127.25362],
#  84999198: [37.32809, 127.111984],
#  84295283: [37.346485, 127.08705],
#  90630483: [37.16497, 127.31106],
#  83559278: [37.323406, 127.06122],
# ...

# %%
df_all = pd.DataFrame(columns=["best_name", "apt_parking_name", "거리차이", "score"])

for i in range(0, len(best_1_dict)) :
    best_nm = list(best_1_dict.keys())[i]
    best_xy = list(best_1_dict.items())[i][1]

    for j in range(0, len(apt_parking_best_dict)) :
        apt_parking_nm = list(apt_parking_best_dict.keys())[j]
        apt_parking_xy = list(apt_parking_best_dict.items())[j][1]

        ## 최종 거리 계산 결과값
        result = haversine(best_xy, apt_parking_xy, unit='m')

        score = 0
        if result <= 200:
            score = 5
        elif 200 < result <= 400:
            score = 4
        elif 400 < result <= 600:
            score = 3
        elif 600 < result <= 800:
            score = 2
        elif 800 < result <= 1000:
            score = 1
        df_all = pd.concat([df_all, 
                        pd.DataFrame({'best_name':[best_nm],'apt_parking_name':[apt_parking_nm], '거리차이':[result], 'score':[score]})], ignore_index=True)
df_all
# Out:
#        best_name apt_parking_name          거리차이 score
# 0       84935149      역북신원아침도시아파트  10345.258535     0
# 1       84935149          양지포레스토리  17592.187991     0
# 2       84935149       양우내안애에듀퍼스트  11366.312131     0
# 3       84935149        힉스유타워 아파트   4394.988708     0
# 4       84935149       성복역 KCC스위첸   4207.286331     0
# ...          ...              ...           ...   ...
# 146935  86839118     죽전7차현대홈타운1단지   5942.457647     0
# 146936  86839118         기흥더샵프라임뷰   9104.638903     0
# 146937  86839118       기흥역롯데캐슬스카이  11047.868929     0
# 146938  86839118     힐스테이트 서천 아파트  14604.229513     0
# 146939  86839118  역북2단지 우남퍼스트빌아파트  11534.825471     0
#
# [146940 rows x 4 columns]

# %%
df_all_1 = df_all[df_all['score'] == 5]
df_all_1
# Out:
#        best_name   apt_parking_name        거리차이 score
# 100     84935149          연원마을성원아파트   56.648793     5
# 309     84935149         연원마을삼성명가타운  195.631652     5
# 1015    84471214            신정마을9단지  149.074041     5
# 2159    84839092          원대마을한신아파트   28.641098     5
# 2643    86375006            백현마을코아루  136.622666     5
# ...          ...                ...         ...   ...
# 141180  84935089               구갈우림  194.456491     5
# 143228  84455094  용인기흥 효성해링턴플레이스아파트  132.749856     5
# 143494  84455094          청현마을기흥데시앙   63.331192     5
# 143495  84455094             대명레이크빌   45.425874     5
# 144162  87846891              인정멜로디   32.962523     5
#
# [323 rows x 4 columns]

# %%
df_all_1 = df_all_1.groupby('apt_parking_name')['score'].sum()
df_all_1 = df_all_1.reset_index()
df_all_1 = df_all_1.rename(columns = {'score' : '1_score'})
df_all_1
# Out:
#      apt_parking_name 1_score
# 0    e편한세상 용인한숲시티 2단지       5
# 1    e편한세상 용인한숲시티 5단지       5
# 2     e편한세상 용인한숲시티6단지       5
# 3      e편한세상용인한숲시티4단지       5
# 4          강남마을코오롱하늘채      10
# ..                ...     ...
# 223    흥덕마을13단지경남아너스빌      10
# 224   흥덕마을14단지 호반베르디움      10
# 225         흥덕마을주공4단지       5
# 226        흥덕우미린레이크포레       5
# 227           힐스테이트기흥      10
#
# [228 rows x 2 columns]

# %%
re1 = pd.merge(left=df_all_5, right=df_all_4, how='outer', on='apt_parking_name')
re1
# Out:
#              apt_parking_name 5_score 4_score
# 0                   갈현마을현대홈타운      15       5
# 1                강남마을자연앤4,6단지       5      10
# 2                    광교경남아너스빌      10     NaN
# 3                    광교마을45단지       5     NaN
# 4    광교상떼빌파크뷰(구 상현마을성원상떼빌아파트)      15     NaN
# ..                        ...     ...     ...
# 322            흥덕마을13단지경남아너스빌     NaN       5
# 323                 흥덕마을주공4단지     NaN      10
# 324                흥덕우미린레이크포레     NaN      10
# 325                 힐스테이트 광교산     NaN      10
# 326                   힐스테이트기흥     NaN      10
#
# [327 rows x 3 columns]

# %%
re2 = pd.merge(left=re1, right=df_all_3, how='outer', on='apt_parking_name')
re2
# Out:
#              apt_parking_name 5_score 4_score 3_score
# 0                   갈현마을현대홈타운      15       5     NaN
# 1                강남마을자연앤4,6단지       5      10       5
# 2                    광교경남아너스빌      10     NaN       5
# 3                    광교마을45단지       5     NaN       5
# 4    광교상떼빌파크뷰(구 상현마을성원상떼빌아파트)      15     NaN       5
# ..                        ...     ...     ...     ...
# 384                한천마을금광베네스타     NaN     NaN       5
# 385             현인마을대림이편한세상3차     NaN     NaN       5
# 386                호반써밋 레이크파크     NaN     NaN       5
# 387                      호수청구     NaN     NaN       5
# 388                 효천마을신안인스빌     NaN     NaN      10
#
# [389 rows x 4 columns]

# %%
re3 = pd.merge(left=re2, right=df_all_2, how='outer', on='apt_parking_name')
re3
# Out:
#              apt_parking_name 5_score 4_score 3_score 2_score
# 0                   갈현마을현대홈타운      15       5     NaN       5
# 1                강남마을자연앤4,6단지       5      10       5      10
# 2                    광교경남아너스빌      10     NaN       5       5
# 3                    광교마을45단지       5     NaN       5       5
# 4    광교상떼빌파크뷰(구 상현마을성원상떼빌아파트)      15     NaN       5     NaN
# ..                        ...     ...     ...     ...     ...
# 421             현인마을대림이편한세상2차     NaN     NaN     NaN       5
# 422                 화성파크드림프라브     NaN     NaN     NaN       5
# 423           흥덕마을14단지 호반베르디움     NaN     NaN     NaN       5
# 424              흥덕마을7단지힐스테이트     NaN     NaN     NaN      10
# 425              힐스테이트 구성 아파트     NaN     NaN     NaN       5
#
# [426 rows x 5 columns]

# %%
re4 = pd.merge(left=re3, right=df_all_1, how='outer', on='apt_parking_name')
re4
# Out:
#              apt_parking_name 5_score 4_score 3_score 2_score 1_score
# 0                   갈현마을현대홈타운      15       5     NaN       5     NaN
# 1                강남마을자연앤4,6단지       5      10       5      10     NaN
# 2                    광교경남아너스빌      10     NaN       5       5      15
# 3                    광교마을45단지       5     NaN       5       5       5
# 4    광교상떼빌파크뷰(구 상현마을성원상떼빌아파트)      15     NaN       5     NaN      10
# ..                        ...     ...     ...     ...     ...     ...
# 435                 성현마을광명샤인빌     NaN     NaN     NaN     NaN       5
# 436                  신봉마을자이3차     NaN     NaN     NaN     NaN       5
# 437          용인 구성역 효성해링턴플레이스     NaN     NaN     NaN     NaN       5
# 438                     우림홀인원     NaN     NaN     NaN     NaN       5
# 439          이편한세상 용인한숲시티 3단지     NaN     NaN     NaN     NaN       5
#
# [440 rows x 6 columns]

# %%
df_aptP_score = re4.fillna(0)
df_aptP_score
# Out:
#              apt_parking_name  5_score  4_score  3_score  2_score  1_score
# 0                   갈현마을현대홈타운       15        5        0        5        0
# 1                강남마을자연앤4,6단지        5       10        5       10        0
# 2                    광교경남아너스빌       10        0        5        5       15
# 3                    광교마을45단지        5        0        5        5        5
# 4    광교상떼빌파크뷰(구 상현마을성원상떼빌아파트)       15        0        5        0       10
# ..                        ...      ...      ...      ...      ...      ...
# 435                 성현마을광명샤인빌        0        0        0        0        5
# 436                  신봉마을자이3차        0        0        0        0        5
# 437          용인 구성역 효성해링턴플레이스        0        0        0        0        5
# 438                     우림홀인원        0        0        0        0        5
# 439          이편한세상 용인한숲시티 3단지        0        0        0        0        5
#
# [440 rows x 6 columns]

# %%
# total
df_aptP_score['Total'] = df_aptP_score['5_score']*5 + df_aptP_score['4_score']*4 + df_aptP_score['3_score']*3 + df_aptP_score['2_score']*2 + df_aptP_score['1_score']*1
df_aptP_score
# Out:
#              apt_parking_name  5_score  4_score  3_score  2_score  1_score  \
# 0                   갈현마을현대홈타운       15        5        0        5        0
# 1                강남마을자연앤4,6단지        5       10        5       10        0
# 2                    광교경남아너스빌       10        0        5        5       15
# 3                    광교마을45단지        5        0        5        5        5
# 4    광교상떼빌파크뷰(구 상현마을성원상떼빌아파트)       15        0        5        0       10
# ..                        ...      ...      ...      ...      ...      ...
# 435                 성현마을광명샤인빌        0        0        0        0        5
# 436                  신봉마을자이3차        0        0        0        0        5
# 437          용인 구성역 효성해링턴플레이스        0        0        0        0        5
# 438                     우림홀인원        0        0        0        0        5
# 439          이편한세상 용인한숲시티 3단지        0        0        0        0        5
#
#      Total
# 0      105
# 1      100
# 2       90
# 3       55
# ...

# %%
# 저장
df_aptP_score.to_csv('./res/아파트주자창점수_re.csv')
